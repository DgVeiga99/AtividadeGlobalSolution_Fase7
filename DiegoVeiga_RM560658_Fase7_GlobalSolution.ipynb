# %% [markdown]
# ==========================================================================
# # 📁 **ATIVIDADE FIAP - Global Solution**
# ==========================================================================
#
# **Autor.....:** Diego Nunes Veiga
#
# **RM........:** 560658
#
# **Turma...:** Graduação - 1TIAOR
#
# **Data......:** 01/06/2025
#
# ==========================================================================

# %%
# Importação das bibliotecas
import warnings
import os
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_absolute_error,mean_squared_error
from sklearn.cluster import KMeans, DBSCAN

# %% [markdown]
# ## ↪ **DESASTRE - Vale do Itajaí 2008**
#
# **Mês do ocorrido:** Novembro
#
# **Data do ocorrido:** N/A

# %% [markdown]
# ### **Leitura dos dados**

# %%
# === Leitura dos dados de entrada ===

input_2008 = [
    "INMET_S_SC_A841_JOACABA_01-01-2008_A_31-12-2008.xlsx",
    "INMET_S_SC_A860_CURITIBANOS_28-02-2008_A_31-12-2008.xlsx",
    "INMET_S_SC_A861_RIO DO CAMPO_10-03-2008_A_31-12-2008.xlsx",
    "INMET_S_SC_A863_ITUPORANGA_04-03-2008_A_31-12-2008.xlsx"
    ]

output_2008 = []

# %%
# === Designação do mês de desastre ===

# Mês com desastre no formato (ano, mês)
meses_com_desastre = [(2008, 11)]
meses_interesse = [(2008,10),(2008, 11)]

# %%
# === Formatação dos dados ===

for arquivo in input_2008:

  # Lê os metadados para obter a cidade
  df_cidade = pd.read_excel(arquivo, nrows=8)
  cidade = df_cidade.iloc[1, 1]

  # Lê os dados ignorando os metadados
  df_dados = pd.read_excel(arquivo, skiprows=8)

  # Adiciona a cidade em todos os registros
  df_dados["CIDADE"] = cidade

  # Converte a coluna de data para datetime (essencial para comparar ano e mês)
  df_dados['DATA (YYYY-MM-DD)'] = pd.to_datetime(df_dados['DATA (YYYY-MM-DD)'])

  # Filtra apenas os dados nas datas de interesse
  df_dados = df_dados[
      df_dados['DATA (YYYY-MM-DD)'].apply(lambda d: (d.year, d.month) in meses_interesse)]

  # Marca como 1 o valor de desastre para datas que estão nos meses indicados
  df_dados['DESASTRE'] = df_dados['DATA (YYYY-MM-DD)'].apply(
      lambda d: 1 if (d.year, d.month) in meses_com_desastre else 0
      )

  # Salva o resultado final
  output_2008.append(df_dados)

# %% [markdown]
# ## ↪ **DESASTRE - Blumenau 2023**
#
# **Mês do ocorrido:** Novembro
#
# **Data do ocorrido:** N/A

# %% [markdown]
# ### **Leitura dos dados**

# %%
# === Leitura dos dados de entrada ===

input_2023 = [
    "INMET_S_SC_A862_RIO NEGRINHO_01-01-2023_A_31-12-2023.xlsx",
    "INMET_S_SC_A863_ITUPORANGA_01-01-2023_A_31-12-2023.xlsx",
    "INMET_S_SC_A817_INDAIAL_01-01-2023_A_31-12-2023.xlsx",
    ]

output_2023 = []

# %%
# === Designação do mês de desastre ===

# Mês com desastre no formato (ano, mês)
meses_com_desastre = [(2023, 11)]
meses_interesse = [(2023,10),(2023, 11)]

# %%
# === Formatação dos dados ===

for arquivo in input_2023:

  # Lê os metadados para obter a cidade
  df_cidade = pd.read_excel(arquivo, nrows=8)
  cidade = df_cidade.iloc[1, 1]

  # Lê os dados ignorando os metadados
  df_dados = pd.read_excel(arquivo, skiprows=8)

  # Padroniza o nome da coluna de data
  df_dados.rename(columns={"Data": "DATA (YYYY-MM-DD)"}, inplace=True)

  # Converte a coluna de data
  df_dados['DATA (YYYY-MM-DD)'] = pd.to_datetime(df_dados['DATA (YYYY-MM-DD)'])

  # Adiciona a cidade
  df_dados["CIDADE"] = cidade

  # Filtra apenas os dados nas datas de interesse
  df_dados = df_dados[
      df_dados['DATA (YYYY-MM-DD)'].apply(lambda d: (d.year, d.month) in meses_interesse)]

  # Marca como desastre os meses definidos
  df_dados['DESASTRE'] = df_dados['DATA (YYYY-MM-DD)'].apply(
      lambda d: 1 if (d.year, d.month) in meses_com_desastre else 0
  )

  # Adiciona na lista final
  output_2023.append(df_dados)

# %% [markdown]
# ## ↪ **DESASTRE - Rio Grande do Sul 2024**
#
# **Mês do ocorrido:** Abril e Maio
#
# **Data do ocorrido:** N/A

# %% [markdown]
# ### **Leitura dos dados**

# %%
# === Leitura dos dados de entrada ===

input_2024 = [
    "INMET_S_RS_A801_PORTO ALEGRE - JARDIM BOTANICO_01-01-2024_A_31-12-2024.xlsx",
    "INMET_S_RS_A879_CANELA_01-01-2024_A_31-12-2024.xlsx",
    "INMET_S_RS_A880_VACARIA_01-01-2024_A_31-12-2024.xlsx",
    "INMET_S_RS_A893_ENCRUZILHADA DO SUL_01-01-2024_A_31-12-2024.xlsx",
    "INMET_S_RS_A894_SERAFINA CORREA_01-01-2024_A_31-12-2024.xlsx",
    "INMET_S_RS_B807_PORTO ALEGRE- BELEM NOVO_01-01-2024_A_31-12-2024.xlsx"
]

output_2024 = []

# %%
# === Designação do mês de desastre ===

# Mês com desastre no formato (ano, mês)
meses_com_desastre = [(2024, 4),(2024, 5)]
meses_interesse = [(2024, 3),(2024, 4),(2024, 5)]

# %%
# === Formatação dos dados ===

for arquivo in input_2024:

  # Lê os metadados para obter a cidade
  df_cidade = pd.read_excel(arquivo, nrows=8)
  cidade = df_cidade.iloc[1, 1]

  # Lê os dados ignorando os metadados
  df_dados = pd.read_excel(arquivo, skiprows=8)

  # Padroniza o nome da coluna de data
  df_dados.rename(columns={"Data": "DATA (YYYY-MM-DD)"}, inplace=True)

  # Converte a coluna de data
  df_dados['DATA (YYYY-MM-DD)'] = pd.to_datetime(df_dados['DATA (YYYY-MM-DD)'])

  # Adiciona a cidade
  df_dados["CIDADE"] = cidade

  # Filtra apenas os dados nas datas de interesse
  df_dados = df_dados[
      df_dados['DATA (YYYY-MM-DD)'].apply(lambda d: (d.year, d.month) in meses_interesse)]

  # Marca como desastre os meses definidos
  df_dados['DESASTRE'] = df_dados['DATA (YYYY-MM-DD)'].apply(
      lambda d: 1 if (d.year, d.month) in meses_com_desastre else 0
  )

  # Adiciona na lista final
  output_2024.append(df_dados)

# %% [markdown]
# ## ↪ **CONCATENANDO OS DADOS**

# %% [markdown]
# ### **Transformação na tabela base**

# %%
# Concatena todos os DataFrames das listas em um único DataFrame
dados_unificados = pd.concat(output_2008 + output_2023 + output_2024, ignore_index=True)

# %%
# Apresentação dos dados Resultantes

dados_unificados.info()
print('\n')
dados_unificados.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23496 entries, 0 to 23495
# Data columns (total 23 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   DATA (YYYY-MM-DD)                                      23496 non-null  datetime64[ns]
#  1   HORA (UTC)                                             5856 non-null   object
#  2   PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                       20994 non-null  float64
#  3   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  20994 non-null  float64
#  4   PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)        20962 non-null  float64
#  5   PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)       20962 non-null  float64
#  6   RADIACAO GLOBAL (KJ/m²)                                5856 non-null   float64
#  7   TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)           20994 non-null  float64
# ...

# %%
dados_unificados = dados_unificados.rename(columns={
    'DATA (YYYY-MM-DD)' :                                         "Data (YYYY-MM-DD)",
    'HORA (UTC)':                                                 "Hora (UTC)",
    'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)':                           "Precipitacao (mm)",
    'PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)':      "Pressão Atmosférica (mB)",
    'PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)':            "Pressão Máxima (mB)",
    'PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)':           "Pressão Mínima (mB)",
    'RADIACAO GLOBAL (KJ/m²)':                                    "Radiacao Global (KJ/m²)",
    'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)':               "Temperatura do Ar (°C)",
    'TEMPERATURA DO PONTO DE ORVALHO (°C)':                       "Ponto de Orvalho (°C)",
    'TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)':                 "Temperatura Mínima (°C)",
    'TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)':                 "Temperatura Máxima (°C)",
    'TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)':           "Temperatura Orvalho Máxima (°C)",
    'TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)':           "Temperatura Orvalho Mínima (°C)",
    'UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)':                   "Umidade Máxima (%)",
    'UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)':                   "Umidade Mínima (%)",
    'UMIDADE RELATIVA DO AR, HORARIA (%)':                        "Umidade Relativa (%)",
    'VENTO, DIREÇÃO HORARIA (gr) (° (gr))':                       "Direção Vento (°)",
    'VENTO, RAJADA MAXIMA (m/s)':                                 "Vento máximo (m/s)",
    'VENTO, VELOCIDADE HORARIA (m/s)':                            "Vento hora (m/s)",
    'DESASTRE':                                                   "Desastre Natural",
    'CIDADE':                                                     "Cidade",
    'Hora UTC':                                                   "Hora UTC",
    'RADIACAO GLOBAL (Kj/m²)':                                    "Radiação Clobal (Kj/m²)"
})

# %%
# Apresentação dos dados Resultantes

dados_unificados.info()
dados_unificados.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23496 entries, 0 to 23495
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Data (YYYY-MM-DD)                23496 non-null  datetime64[ns]
#  1   Hora (UTC)                       5856 non-null   object
#  2   Precipitacao (mm)                20994 non-null  float64
#  3   Pressão Atmosférica (mB)         20994 non-null  float64
#  4   Pressão Máxima (mB)              20962 non-null  float64
#  5   Pressão Mínima (mB)              20962 non-null  float64
#  6   Radiacao Global (KJ/m²)          5856 non-null   float64
#  7   Temperatura do Ar (°C)           20994 non-null  float64
#  8   Ponto de Orvalho (°C)            20957 non-null  float64
#  9   Temperatura Máxima (°C)          20962 non-null  float64
#  10  Temperatura Mínima (°C)          20962 non-null  float64
# ...

# %%
# Salva em um único arquivo Excel
dados_unificados.to_excel("Base_Unificada_INMET.xlsx", index=False)

print("Todos os dados foram concatenados e salvos como 'Base_Unificada_INMET.xlsx'")
# Out:
# Todos os dados foram concatenados e salvos como 'Base_Unificada_INMET.xlsx'
